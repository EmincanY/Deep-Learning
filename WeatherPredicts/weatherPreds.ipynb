# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Lets Look Our Data and Select our Features for Regression

# %%
df = pd.read_csv("weather_data_Izmir.csv")
df.head()
# Out:
#              date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0  2021-05-01 00:00:00        26        18           0.0     11.6        6
# 1  2021-05-01 01:00:00        26        18           0.0     11.6        6
# 2  2021-05-01 02:00:00        26        18           0.0     11.6        6
# 3  2021-05-01 03:00:00        26        18           0.0     11.6        6
# 4  2021-05-01 04:00:00        26        18           0.0     11.6        6
#
#    moon_illumination  moonrise   moonset   sunrise  ... humidity  precipMM  \
# 0                 70  12:19 AM  09:44 AM  06:16 AM  ...       58       0.0
# 1                 70  12:19 AM  09:44 AM  06:16 AM  ...       58       0.0
# 2                 70  12:19 AM  09:44 AM  06:16 AM  ...       58       0.0
# 3                 70  12:19 AM  09:44 AM  06:16 AM  ...       58       0.0
# 4                 70  12:19 AM  09:44 AM  06:16 AM  ...       57       0.0
#
#    pressure  tempC  visibility  winddirDegree  windspeedKmph    location  \
# 0      1015     18          10            143              4  İZMİR-URLA
# 1      1015     18          10            139              5  İZMİR-URLA
# 2      1015     18          10            135              5  İZMİR-URLA
# 3      1015     18          10            131              5  İZMİR-URLA
# 4      1015     18          10            131              5  İZMİR-URLA
#
#       İL  İLÇE
# 0  İZMİR  URLA
# 1  İZMİR  URLA
# 2  İZMİR  URLA
# 3  İZMİR  URLA
# 4  İZMİR  URLA
#
# [5 rows x 27 columns]

# %%
df.rename({"İL" : "City" , "İLÇE" : "SubCity"},axis=1 , inplace=True)
df.head()
# Out:
#              date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0  2021-05-01 00:00:00        26        18           0.0     11.6        6
# 1  2021-05-01 01:00:00        26        18           0.0     11.6        6
# 2  2021-05-01 02:00:00        26        18           0.0     11.6        6
# 3  2021-05-01 03:00:00        26        18           0.0     11.6        6
# 4  2021-05-01 04:00:00        26        18           0.0     11.6        6
#
#    moon_illumination  moonrise   moonset   sunrise  ... humidity  precipMM  \
# 0                 70  12:19 AM  09:44 AM  06:16 AM  ...       58       0.0
# 1                 70  12:19 AM  09:44 AM  06:16 AM  ...       58       0.0
# 2                 70  12:19 AM  09:44 AM  06:16 AM  ...       58       0.0
# 3                 70  12:19 AM  09:44 AM  06:16 AM  ...       58       0.0
# 4                 70  12:19 AM  09:44 AM  06:16 AM  ...       57       0.0
#
#    pressure  tempC  visibility  winddirDegree  windspeedKmph    location  \
# 0      1015     18          10            143              4  İZMİR-URLA
# 1      1015     18          10            139              5  İZMİR-URLA
# 2      1015     18          10            135              5  İZMİR-URLA
# 3      1015     18          10            131              5  İZMİR-URLA
# 4      1015     18          10            131              5  İZMİR-URLA
#
#     City  SubCity
# 0  İZMİR     URLA
# 1  İZMİR     URLA
# 2  İZMİR     URLA
# 3  İZMİR     URLA
# 4  İZMİR     URLA
#
# [5 rows x 27 columns]

# %%
df.dtypes
# Out:
# date_time             object
# maxtempC               int64
# mintempC               int64
# totalSnow_cm         float64
# sunHour              float64
# uvIndex                int64
# moon_illumination      int64
# moonrise              object
# moonset               object
# sunrise               object
# sunset                object
# DewPointC              int64
# FeelsLikeC             int64
# HeatIndexC             int64
# WindChillC             int64
# WindGustKmph           int64
# cloudcover             int64
# humidity               int64
# precipMM             float64
# pressure               int64
# tempC                  int64
# visibility             int64
# winddirDegree          int64
# windspeedKmph          int64
# location              object
# City                  object
# SubCity               object
# dtype: object

# %%
df.shape
# Out:
# (525960, 27)

# %%
df["date_time"] = df["date_time"].astype("datetime64")

# %%
df.set_index("date_time" , drop=True , inplace=True)
df.head()
# Out:
#                      maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# date_time
# 2021-05-01 00:00:00        26        18           0.0     11.6        6
# 2021-05-01 01:00:00        26        18           0.0     11.6        6
# 2021-05-01 02:00:00        26        18           0.0     11.6        6
# 2021-05-01 03:00:00        26        18           0.0     11.6        6
# 2021-05-01 04:00:00        26        18           0.0     11.6        6
#
#                      moon_illumination  moonrise   moonset   sunrise  \
# date_time
# 2021-05-01 00:00:00                 70  12:19 AM  09:44 AM  06:16 AM
# 2021-05-01 01:00:00                 70  12:19 AM  09:44 AM  06:16 AM
# 2021-05-01 02:00:00                 70  12:19 AM  09:44 AM  06:16 AM
# 2021-05-01 03:00:00                 70  12:19 AM  09:44 AM  06:16 AM
# 2021-05-01 04:00:00                 70  12:19 AM  09:44 AM  06:16 AM
#
#                        sunset  ...  humidity  precipMM  pressure  tempC  \
# date_time                      ...
# 2021-05-01 00:00:00  08:04 PM  ...        58       0.0      1015     18
# 2021-05-01 01:00:00  08:04 PM  ...        58       0.0      1015     18
# 2021-05-01 02:00:00  08:04 PM  ...        58       0.0      1015     18
# 2021-05-01 03:00:00  08:04 PM  ...        58       0.0      1015     18
# 2021-05-01 04:00:00  08:04 PM  ...        57       0.0      1015     18
#
#                      visibility  winddirDegree  windspeedKmph    location  \
# date_time
# 2021-05-01 00:00:00          10            143              4  İZMİR-URLA
# 2021-05-01 01:00:00          10            139              5  İZMİR-URLA
# 2021-05-01 02:00:00          10            135              5  İZMİR-URLA
# 2021-05-01 03:00:00          10            131              5  İZMİR-URLA
# 2021-05-01 04:00:00          10            131              5  İZMİR-URLA
#
#                       City  SubCity
# date_time
# 2021-05-01 00:00:00  İZMİR     URLA
# 2021-05-01 01:00:00  İZMİR     URLA
# 2021-05-01 02:00:00  İZMİR     URLA
# 2021-05-01 03:00:00  İZMİR     URLA
# 2021-05-01 04:00:00  İZMİR     URLA
#
# [5 rows x 26 columns]

# %%
df.dtypes
# Out:
# maxtempC               int64
# mintempC               int64
# totalSnow_cm         float64
# sunHour              float64
# uvIndex                int64
# moon_illumination      int64
# moonrise              object
# moonset               object
# sunrise               object
# sunset                object
# DewPointC              int64
# FeelsLikeC             int64
# HeatIndexC             int64
# WindChillC             int64
# WindGustKmph           int64
# cloudcover             int64
# humidity               int64
# precipMM             float64
# pressure               int64
# tempC                  int64
# visibility             int64
# winddirDegree          int64
# windspeedKmph          int64
# location              object
# City                  object
# SubCity               object
# dtype: object

# %%
df = df.drop(["moonrise","moonset","sunset", "sunrise","location","SubCity"] , axis=1)
df.head()
# Out:
#                      maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# date_time
# 2021-05-01 00:00:00        26        18           0.0     11.6        6
# 2021-05-01 01:00:00        26        18           0.0     11.6        6
# 2021-05-01 02:00:00        26        18           0.0     11.6        6
# 2021-05-01 03:00:00        26        18           0.0     11.6        6
# 2021-05-01 04:00:00        26        18           0.0     11.6        6
#
#                      moon_illumination  DewPointC  FeelsLikeC  HeatIndexC  \
# date_time
# 2021-05-01 00:00:00                 70         10          18          18
# 2021-05-01 01:00:00                 70         10          18          18
# 2021-05-01 02:00:00                 70         10          18          18
# 2021-05-01 03:00:00                 70         10          18          18
# 2021-05-01 04:00:00                 70         10          18          19
#
#                      WindChillC  WindGustKmph  cloudcover  humidity  precipMM  \
# date_time
# 2021-05-01 00:00:00          18             9          23        58       0.0
# 2021-05-01 01:00:00          18            10          19        58       0.0
# 2021-05-01 02:00:00          18            10          14        58       0.0
# 2021-05-01 03:00:00          18            10           9        58       0.0
# 2021-05-01 04:00:00          18            10          19        57       0.0
#
#                      pressure  tempC  visibility  winddirDegree  \
# date_time
# 2021-05-01 00:00:00      1015     18          10            143
# 2021-05-01 01:00:00      1015     18          10            139
# 2021-05-01 02:00:00      1015     18          10            135
# 2021-05-01 03:00:00      1015     18          10            131
# 2021-05-01 04:00:00      1015     18          10            131
#
#                      windspeedKmph   City
# date_time
# 2021-05-01 00:00:00              4  İZMİR
# 2021-05-01 01:00:00              5  İZMİR
# 2021-05-01 02:00:00              5  İZMİR
# 2021-05-01 03:00:00              5  İZMİR
# 2021-05-01 04:00:00              5  İZMİR

# %%
df.dtypes
# Out:
# maxtempC               int64
# mintempC               int64
# totalSnow_cm         float64
# sunHour              float64
# uvIndex                int64
# moon_illumination      int64
# DewPointC              int64
# FeelsLikeC             int64
# HeatIndexC             int64
# WindChillC             int64
# WindGustKmph           int64
# cloudcover             int64
# humidity               int64
# precipMM             float64
# pressure               int64
# tempC                  int64
# visibility             int64
# winddirDegree          int64
# windspeedKmph          int64
# City                  object
# dtype: object

# %%
df.City.value_counts()
# Out:
# İZMİR     327264
# MANİSA    198696
# Name: City, dtype: int64

# %%
df.City = df.City.map({"İZMİR":1 , "MANİSA" : 0})
df.City
# Out:
# date_time
# 2021-05-01 00:00:00    1
# 2021-05-01 01:00:00    1
# 2021-05-01 02:00:00    1
# 2021-05-01 03:00:00    1
# 2021-05-01 04:00:00    1
#                       ..
# 2022-08-30 19:00:00    0
# 2022-08-30 20:00:00    0
# 2022-08-30 21:00:00    0
# 2022-08-30 22:00:00    0
# 2022-08-30 23:00:00    0
# Name: City, Length: 525960, dtype: int64

# %%
df.dtypes
# Out:
# maxtempC               int64
# mintempC               int64
# totalSnow_cm         float64
# sunHour              float64
# uvIndex                int64
# moon_illumination      int64
# DewPointC              int64
# FeelsLikeC             int64
# HeatIndexC             int64
# WindChillC             int64
# WindGustKmph           int64
# cloudcover             int64
# humidity               int64
# precipMM             float64
# pressure               int64
# tempC                  int64
# visibility             int64
# winddirDegree          int64
# windspeedKmph          int64
# City                   int64
# dtype: object

# %% [markdown]
# # Lets look Graphs

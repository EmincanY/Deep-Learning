# %%
# Class weight a typical method. We'll use a different method now.
# We will use focal loss.

# %%
import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_text

import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

plt.rcParams["figure.figsize"] = (12,8)

print(f"Version: {tf.__version__}")
# Out:
# Version: 2.10.1

# %% [markdown]
# # Import data

# %%
url = "https://archive.org/download/fine-tune-bert-tensorflow-train.csv/train.csv.zip"

df = pd.read_csv(url, compression='zip')
df.shape
# Out:
# (1306122, 3)

# %%
df.head()
# Out:
#                     qid                                      question_text  \
# 0  00002165364db923c7e6  How did Quebec nationalists see their province...
# 1  000032939017120e6e44  Do you have an adopted dog, how would you enco...
# 2  0000412ca6e4628ce2cf  Why does velocity affect time? Does velocity a...
# 3  000042bf85aa498cd78e  How did Otto von Guericke used the Magdeburg h...
# 4  0000455dfa3e01eae3af  Can I convert montra helicon D to a mountain b...
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
ax = sns.countplot(data = df, x = 'target')

plt.xticks(size = 16)
plt.xlabel("Target Label" , size = 16)
plt.yticks(size = 16)
plt.ylabel('Total', size = 16)
ax.yaxis.set_major_formatter(ticker.EngFormatter())

ax.set_xticklabels(ax.get_xticklabels(), ha='center' )
total = len(df)

for p in ax.patches : 
    perc = f'{100 * p.get_height() / total:.1f}%\n'
    x = p.get_x() + p.get_width() / 2
    y = p.get_height()
    ax.annotate(perc , (x,y) , ha="center", va = 'center' , fontsize = 20)

plt.tight_layout()
plt.title('Label Contribution' , fontsize = 18)
plt.show()

# %% [markdown]
# # TF.Data Pipeline

# %%
feats, labels = df['question_text'] , df['target']

# %%
trainVal_feats , X_test, trainVal_labels , y_test = train_test_split(feats , labels, test_size= 0.2, stratify= labels, random_state= 53)

# %%
trainVal_feats.shape , trainVal_labels.shape
# Out:
# ((1044897,), (1044897,))

# %%
X_train , X_val , y_train , y_val = train_test_split(
                                                    trainVal_feats ,
                                                    trainVal_labels , 
                                                    train_size = 0.8 , 
                                                    stratify= trainVal_labels ,
                                                    random_state= 53                                             
                                                    
)

# %%
X_train.shape , y_train.shape
# Out:
# ((835917,), (835917,))

# %%
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) # You can use tf.data.Dataset.from_generator() for bigger data. You can save RAM with this way.
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val))
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test))

# %%
train_ds
# Out:
# <TensorSliceDataset element_spec=(TensorSpec(shape=(), dtype=tf.string, name=None), TensorSpec(shape=(), dtype=tf.int64, name=None))>

# %%
next(iter(train_ds))
# Out:
# (<tf.Tensor: shape=(), dtype=string, numpy=b'This happened to medo teachers sometimes lose trust in their student if the student has told them something (like if they self harm or starve or etc)?'>,
#  <tf.Tensor: shape=(), dtype=int64, numpy=0>)

# %%
train_ds = train_ds.shuffle(4096).batch(2048, drop_remainder= False).prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.batch(2048).prefetch(tf.data.AUTOTUNE)
test_ds = test_ds.batch(2048).prefetch(tf.data.AUTOTUNE)

# %%
train_ds
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None,), dtype=tf.string, name=None), TensorSpec(shape=(None,), dtype=tf.int64, name=None))>

# %% [markdown]
# # Create Model

# %%
embedding_link = "https://tfhub.dev/google/tf2-preview/nnlm-en-dim128/1"

embedding = hub.KerasLayer(
    embedding_link
)
# Out:
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.data_structures has been moved to tensorflow.python.trackable.data_structures. The old module will be deleted in version 2.11.

# %%
embedding

# %%
sample = tf.constant(['hi guys bro' , 'Hello my friend how are you'])
sample
# Out:
# <tf.Tensor: shape=(2,), dtype=string, numpy=array([b'hi guys bro', b'Hello my friend how are you'], dtype=object)>

# %%
# embedding(sample)

# %%
input_layer = tf.keras.Input(batch_input_shape = (None, ), dtype = tf.string)
embedding_output = embedding(input_layer)

# 1.branch
x = tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis= -1))(embedding_output)
x = tf.keras.layers.Conv1D(filters = 16, kernel_size= 5)(x)
x = tf.nn.silu(x)
x = tf.keras.layers.AveragePooling1D()(x)
x = tf.keras.layers.Conv1D(filters= 32 , kernel_size= 3)(x)
x = tf.nn.silu(x)
x = tf.keras.layers.GlobalAveragePooling1D()(x)

# 2.branch
y = tf.keras.layers.Dense(128)(embedding_output)
y = tf.nn.silu(y)

merged = tf.keras.layers.Concatenate()([x, y])

final_layer = tf.keras.layers.Dense(1)(merged)
final_layer = tf.nn.sigmoid(final_layer)

model_normal = tf.keras.Model(input_layer, final_layer)

# %%
tf.keras.utils.plot_model(model_normal, show_shapes= True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
model_normal.layers[1].trainable = True

# %%
model_normal.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_15 (InputLayer)          [(None,)]            0           []
#
#  keras_layer (KerasLayer)       (None, 128)          124642688   ['input_15[0][0]']
#
#  lambda_11 (Lambda)             (None, 128, 1)       0           ['keras_layer[13][0]']
#
#  conv1d_21 (Conv1D)             (None, 124, 16)      96          ['lambda_11[0][0]']
#
#  tf.nn.silu_24 (TFOpLambda)     (None, 124, 16)      0           ['conv1d_21[0][0]']
#
#  average_pooling1d_8 (AveragePo  (None, 62, 16)      0           ['tf.nn.silu_24[0][0]']
#  oling1D)
#
#  conv1d_22 (Conv1D)             (None, 60, 32)       1568        ['average_pooling1d_8[0][0]']
#
#  tf.nn.silu_25 (TFOpLambda)     (None, 60, 32)       0           ['conv1d_22[0][0]']
#
#  dense_8 (Dense)                (None, 128)          16512       ['keras_layer[13][0]']
#
#  global_average_pooling1d_4 (Gl  (None, 32)          0           ['tf.nn.silu_25[0][0]']
#  obalAveragePooling1D)
#
#  tf.nn.silu_26 (TFOpLambda)     (None, 128)          0           ['dense_8[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 160)          0           ['global_average_pooling1d_4[0][0
#                                                                  ]',
#                                                                   'tf.nn.silu_26[0][0]']
#
#  dense_9 (Dense)                (None, 1)            161         ['concatenate_8[0][0]']
#
#  tf.math.sigmoid (TFOpLambda)   (None, 1)            0           ['dense_9[0][0]']
#
# ==================================================================================================
# Total params: 124,661,025
# Trainable params: 124,661,025
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# model_focal = tf.keras.models.clone_model(model_normal) # When you clone a model in this way, weights don't save.

# %%
# model_normal.save_weights("starting_point.h5") # We got our weights now

# %%
model_normal.compile(optimizer= 'adam',
                     loss = tf.keras.losses.BinaryCrossentropy(),
                     metrics = [tf.keras.metrics.TruePositives(),
                                tf.keras.metrics.FalseNegatives()])

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
# model_normal(np.array([['Hi']])).numpy()
# Out:
# array([[0.00017122]], dtype=float32)

# %%
def eval_model(
                model,
                threshold,
                dataset
               ):
    y_pred = []
    y_true = []
    
    for x, y in dataset:
        y_pred.append(model(x).numpy())
        y_true.append(y.numpy())
        
    y_pred = np.concatenate(y_pred, axis = 0)
    y_true = np.concatenate(y_true, axis = 0)
    
    y_pred = np.where(y_pred > threshold, 1 ,0)
    
    print(classification_report(y_true , y_pred, digits=4))
    
    plt.figure(figsize=(12, 8))
    sns.heatmap(confusion_matrix(y_true, y_pred), annot = True , fmt= ".4f")
    plt.show()

# %%
eval_model(model_normal , 0.3 , test_ds)
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9763    0.9639    0.9701    245063
#            1     0.5413    0.6460    0.5890     16162
#
#     accuracy                         0.9442    261225
#    macro avg     0.7588    0.8049    0.7795    261225
# weighted avg     0.9494    0.9442    0.9465    261225

# %% [markdown]
# # 2.Model

# %%
model_focal.load_weights("starting_point.h5")

# %%
model_focal.compile(optimizer= 'adam',
                     loss = tf.keras.losses.BinaryFocalCrossentropy(),
                     metrics = [tf.keras.metrics.TruePositives(),
                                tf.keras.metrics.FalseNegatives()])

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    min_lr = 1e-8, verbose= 1 , patience= 3
)

model_focal.fit(train_ds, validation_data= val_ds , epochs = 32, callbacks=[reduce_lr])
# Out:
# Epoch 1/32
# 409/409 [==============================] - 7s 15ms/step - loss: 0.0483 - true_positives_2: 9328.0000 - false_negatives_2: 42390.0000 - val_loss: 0.0406 - val_true_positives_2: 3265.0000 - val_false_negatives_2: 9665.0000 - lr: 0.0010
# Epoch 2/32
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0405 - true_positives_2: 13990.0000 - false_negatives_2: 37728.0000 - val_loss: 0.0403 - val_true_positives_2: 3185.0000 - val_false_negatives_2: 9745.0000 - lr: 0.0010
# Epoch 3/32
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0402 - true_positives_2: 14188.0000 - false_negatives_2: 37530.0000 - val_loss: 0.0399 - val_true_positives_2: 3409.0000 - val_false_negatives_2: 9521.0000 - lr: 0.0010
# Epoch 4/32
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0399 - true_positives_2: 14360.0000 - false_negatives_2: 37358.0000 - val_loss: 0.0396 - val_true_positives_2: 3687.0000 - val_false_negatives_2: 9243.0000 - lr: 0.0010
# Epoch 5/32
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0397 - true_positives_2: 14452.0000 - false_negatives_2: 37266.0000 - val_loss: 0.0393 - val_true_positives_2: 3727.0000 - val_false_negatives_2: 9203.0000 - lr: 0.0010
# Epoch 6/32
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0395 - true_positives_2: 14542.0000 - false_negatives_2: 37176.0000 - val_loss: 0.0391 - val_true_positives_2: 3815.0000 - val_false_negatives_2: 9115.0000 - lr: 0.0010
# Epoch 7/32
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0392 - true_positives_2: 14673.0000 - false_negatives_2: 37045.0000 - val_loss: 0.0389 - val_true_positives_2: 4086.0000 - val_false_negatives_2: 8844.0000 - lr: 0.0010
# Epoch 8/32
# 409/409 [==============================] - 6s 15ms/step - loss: 0.0390 - true_positives_2: 14852.0000 - false_negatives_2: 36866.0000 - val_loss: 0.0386 - val_true_positives_2: 3759.0000 - val_false_negatives_2: 9171.0000 - lr: 0.0010
# Epoch 9/32
# 409/409 [==============================] - 6s 15ms/step - loss: 0.0388 - true_positives_2: 14936.0000 - false_negatives_2: 36782.0000 - val_loss: 0.0384 - val_true_positives_2: 4145.0000 - val_false_negatives_2: 8785.0000 - lr: 0.0010
# Epoch 10/32
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0386 - true_positives_2: 15152.0000 - false_negatives_2: 36566.0000 - val_loss: 0.0382 - val_true_positives_2: 3918.0000 - val_false_negatives_2: 9012.0000 - lr: 0.0010
# Epoch 11/32
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0384 - true_positives_2: 15349.0000 - false_negatives_2: 36369.0000 - val_loss: 0.0380 - val_true_positives_2: 4052.0000 - val_false_negatives_2: 8878.0000 - lr: 0.0010
# Epoch 12/32
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0382 - true_positives_2: 15565.0000 - false_negatives_2: 36153.0000 - val_loss: 0.0379 - val_true_positives_2: 4201.0000 - val_false_negatives_2: 8729.0000 - lr: 0.0010
# Epoch 13/32
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0381 - true_positives_2: 15816.0000 - false_negatives_2: 35902.0000 - val_loss: 0.0378 - val_true_positives_2: 4340.0000 - val_false_negatives_2: 8590.0000 - lr: 0.0010
# Epoch 14/32
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0379 - true_positives_2: 16014.0000 - false_negatives_2: 35704.0000 - val_loss: 0.0376 - val_true_positives_2: 4286.0000 - val_false_negatives_2: 8644.0000 - lr: 0.0010
# Epoch 15/32
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0378 - true_positives_2: 16170.0000 - false_negatives_2: 35548.0000 - val_loss: 0.0375 - val_true_positives_2: 4367.0000 - val_false_negatives_2: 8563.0000 - lr: 0.0010
# Epoch 16/32
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0377 - true_positives_2: 16327.0000 - false_negatives_2: 35391.0000 - val_loss: 0.0374 - val_true_positives_2: 4221.0000 - val_false_negatives_2: 8709.0000 - lr: 0.0010
# Epoch 17/32
# 409/409 [==============================] - 6s 15ms/step - loss: 0.0376 - true_positives_2: 16433.0000 - false_negatives_2: 35285.0000 - val_loss: 0.0374 - val_true_positives_2: 4542.0000 - val_false_negatives_2: 8388.0000 - lr: 0.0010
# Epoch 18/32
# 409/409 [==============================] - 6s 15ms/step - loss: 0.0375 - true_positives_2: 16624.0000 - false_negatives_2: 35094.0000 - val_loss: 0.0373 - val_true_positives_2: 4571.0000 - val_false_negatives_2: 8359.0000 - lr: 0.0010
# Epoch 19/32
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0373 - true_positives_2: 16773.0000 - false_negatives_2: 34945.0000 - val_loss: 0.0372 - val_true_positives_2: 4476.0000 - val_false_negatives_2: 8454.0000 - lr: 0.0010
# Epoch 20/32
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0372 - true_positives_2: 16889.0000 - false_negatives_2: 34829.0000 - val_loss: 0.0371 - val_true_positives_2: 4479.0000 - val_false_negatives_2: 8451.0000 - lr: 0.0010
# Epoch 21/32
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0371 - true_positives_2: 17046.0000 - false_negatives_2: 34672.0000 - val_loss: 0.0370 - val_true_positives_2: 4694.0000 - val_false_negatives_2: 8236.0000 - lr: 0.0010
# Epoch 22/32
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0370 - true_positives_2: 17168.0000 - false_negatives_2: 34550.0000 - val_loss: 0.0369 - val_true_positives_2: 4515.0000 - val_false_negatives_2: 8415.0000 - lr: 0.0010
# Epoch 23/32
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0370 - true_positives_2: 17285.0000 - false_negatives_2: 34433.0000 - val_loss: 0.0369 - val_true_positives_2: 4877.0000 - val_false_negatives_2: 8053.0000 - lr: 0.0010
# Epoch 24/32
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0369 - true_positives_2: 17432.0000 - false_negatives_2: 34286.0000 - val_loss: 0.0368 - val_true_positives_2: 4590.0000 - val_false_negatives_2: 8340.0000 - lr: 0.0010
# Epoch 25/32
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0368 - true_positives_2: 17483.0000 - false_negatives_2: 34235.0000 - val_loss: 0.0367 - val_true_positives_2: 4690.0000 - val_false_negatives_2: 8240.0000 - lr: 0.0010
# Epoch 26/32
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0367 - true_positives_2: 17563.0000 - false_negatives_2: 34155.0000 - val_loss: 0.0367 - val_true_positives_2: 4662.0000 - val_false_negatives_2: 8268.0000 - lr: 0.0010
# Epoch 27/32
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0366 - true_positives_2: 17698.0000 - false_negatives_2: 34020.0000 - val_loss: 0.0366 - val_true_positives_2: 4774.0000 - val_false_negatives_2: 8156.0000 - lr: 0.0010
# Epoch 28/32
# 409/409 [==============================] - 6s 13ms/step - loss: 0.0366 - true_positives_2: 17795.0000 - false_negatives_2: 33923.0000 - val_loss: 0.0366 - val_true_positives_2: 4824.0000 - val_false_negatives_2: 8106.0000 - lr: 0.0010
# Epoch 29/32
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0365 - true_positives_2: 17873.0000 - false_negatives_2: 33845.0000 - val_loss: 0.0365 - val_true_positives_2: 4700.0000 - val_false_negatives_2: 8230.0000 - lr: 0.0010
# Epoch 30/32
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0364 - true_positives_2: 17961.0000 - false_negatives_2: 33757.0000 - val_loss: 0.0365 - val_true_positives_2: 4667.0000 - val_false_negatives_2: 8263.0000 - lr: 0.0010
# Epoch 31/32
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0364 - true_positives_2: 18034.0000 - false_negatives_2: 33684.0000 - val_loss: 0.0365 - val_true_positives_2: 4948.0000 - val_false_negatives_2: 7982.0000 - lr: 0.0010
# Epoch 32/32
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0363 - true_positives_2: 18140.0000 - false_negatives_2: 33578.0000 - val_loss: 0.0364 - val_true_positives_2: 4827.0000 - val_false_negatives_2: 8103.0000 - lr: 0.0010

# %%
eval_model(model_focal,
           0.3,
           test_ds)
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9865    0.8901    0.9358    245063
#            1     0.3284    0.8149    0.4682     16162
#
#     accuracy                         0.8854    261225
#    macro avg     0.6574    0.8525    0.7020    261225
# weighted avg     0.9458    0.8854    0.9069    261225

# %% [markdown]
# # Loss Comparisions

# %%
bce_loss = tf.keras.losses.BinaryCrossentropy(reduction= 'none')
bfce_loss = tf.keras.losses.BinaryFocalCrossentropy(reduction= 'none')

# %%
y_pred = np.array([[0.1], [0.9], [0.2], [0.3]])
y_true = np.array([[0.0], [1.0], [1.0], [0.0]])

# %%
bce_loss(y_pred, y_true)
# Out:
# <tf.Tensor: shape=(4,), dtype=float64, numpy=array([ 1.54249485,  1.54249485, 12.33995878,  4.62748454])>

# %%
bfce_loss(y_pred, y_true) # Focal Loss punish very hard for your wrongs... Most of time its better for imbalanced data.
# Out:
# <tf.Tensor: shape=(4,), dtype=float64, numpy=array([0.01542495, 0.01542495, 7.89757362, 0.41647361])>

# %%
# Done

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import tensorflow.keras.datasets as tfds_datasets
import tqdm

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
pp_dataset_list = dir(tfds_datasets)
for dataset_name in pp_dataset_list:
    print(dataset_name)
# Out:
# __builtins__
# __cached__
# __doc__
# __file__
# __loader__
# __name__
# __package__
# __path__
# __spec__
# _sys
# boston_housing
# cifar10
# cifar100
# fashion_mnist
# imdb
# mnist
# reuters

# %%
dataset_list = tfds.list_builders()
for dataset_name in dataset_list:
    print(dataset_name)
# Out:
# abstract_reasoning
# accentdb
# aeslc
# aflw2k3d
# ag_news_subset
# ai2_arc
# ai2_arc_with_ir
# amazon_us_reviews
# anli
# answer_equivalence
# arc
# asqa
# asset
# assin2
# bair_robot_pushing_small
# bccd
# beans
# bee_dataset
# beir
# big_patent
# bigearthnet
# billsum
# binarized_mnist
# binary_alpha_digits
# ble_wind_field
# blimp
# booksum
# bool_q
# bucc
# c4
# c4_wsrs
# caltech101
# caltech_birds2010
# caltech_birds2011
# cardiotox
# cars196
# cassava
# cats_vs_dogs
# celeb_a
# celeb_a_hq
# cfq
# cherry_blossoms
# chexpert
# cifar10
# cifar100
# cifar100_n
# cifar10_1
# cifar10_corrupted
# cifar10_n
# citrus_leaves
# cityscapes
# civil_comments
# clevr
# clic
# clinc_oos
# cmaterdb
# cnn_dailymail
# coco
# coco_captions
# coil100
# colorectal_histology
# colorectal_histology_large
# common_voice
# conll2002
# conll2003
# controlled_noisy_web_labels
# coqa
# cos_e
# cosmos_qa
# covid19
# covid19sum
# crema_d
# criteo
# cs_restaurants
# curated_breast_imaging_ddsm
# cycle_gan
# ...

# %%
data = tfds.load('oxford_flowers102', split='train', with_info=True)
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# ...
# Dl Completed...: 100%|██████████| 3/3 [05:30<00:00, 121.72s/ url]
# ...
# ...
# Dl Completed...: 100%|██████████| 3/3 [06:41<00:00, 121.72s/ url]
#
# ...
# Dl Completed...: 100%|██████████| 3/3 [06:41<00:00, 121.72s/ url]
#
# ...
# Dl Completed...: 100%|██████████| 3/3 [06:41<00:00, 121.72s/ url]
#
# ...
# Dl Completed...: 100%|██████████| 3/3 [06:42<00:00, 121.72s/ url]
#
# ...
# Dl Completed...: 100%|██████████| 3/3 [06:42<00:00, 121.72s/ url]
#
# ...
# Dl Completed...: 100%|██████████| 3/3 [06:42<00:00, 121.72s/ url]
#
# ...
# Dl Completed...: 100%|██████████| 3/3 [06:42<00:00, 121.72s/ url]
#
# ...
# Dl Completed...: 100%|██████████| 3/3 [06:42<00:00, 121.72s/ url]
#
# ...
# Dl Completed...: 100%|██████████| 3/3 [06:42<00:00, 121.72s/ url]
#
# ...
# Dl Completed...: 100%|██████████| 3/3 [06:42<00:00, 134.24s/ url]
# Dataset oxford_flowers102 downloaded and prepared to C:\Users\Emincan\tensorflow_datasets\oxford_flowers102\2.1.1. Subsequent calls will reuse this data.

# %%
type(data)
# Out:
# tuple

# %%
data[0]
# Out:
# <PrefetchDataset element_spec={'file_name': TensorSpec(shape=(), dtype=tf.string, name=None), 'image': TensorSpec(shape=(None, None, 3), dtype=tf.uint8, name=None), 'label': TensorSpec(shape=(), dtype=tf.int64, name=None)}>
